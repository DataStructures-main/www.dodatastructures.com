# %% [markdown]
# # 🎉 Welcome to CMPSC 301 JupyterLite!
#
# You're using **JupyterLite** - a full Jupyter environment running entirely in your web browser! No installation required.
#
# ## 🚀 Getting Started
#
# This notebook will help you:
# 1. **Install Python packages** (first-time setup)
# 2. Test your Python environment
# 3. Load and explore data
# 4. Create visualizations
# 5. Get comfortable with Jupyter notebooks
#
# ---

# %% [markdown]
# ## 📦 Installing Packages
#
# JupyterLite uses **micropip** to install Python packages. Here's how to install common data science packages:
#
# **Note:** The first time you install packages, it may take a minute to download. Be patient!

# %%
# Install essential data science packages
import micropip

print("📦 Installing packages... (this may take a moment)")
await micropip.install(['numpy', 'pandas', 'matplotlib', 'seaborn'])
print("✅ Packages installed successfully!")

# %% [markdown]
# ## 📦 Installing Packages
#
# JupyterLite uses **micropip** to install Python packages. Here's how to install common data science packages:
#
# **Note:** The first time you install packages, it may take a minute to download. Be patient!

# %%
# Install essential data science packages
import micropip

print("📦 Installing packages... (this may take a moment)")
await micropip.install(['numpy', 'pandas', 'matplotlib', 'seaborn'])
print("✅ Packages installed successfully!")

# %% [markdown]
# ## Part 1: Testing Python Environment
#
# Let's verify that the essential data science libraries are available:

# %%
# Import core libraries
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("✅ Python Environment Test")
print("="*50)
print(f"Python version: {sys.version}")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print("\n🎉 All libraries loaded successfully!")

# %% [markdown]
# ## Part 2: Your First Data Analysis
#
# Let's create a simple dataset and analyze it:

# %%
# Create sample data
np.random.seed(42)

data = {
    'Student': [f'Student {i}' for i in range(1, 11)],
    'Math': np.random.randint(70, 100, 10),
    'Science': np.random.randint(65, 95, 10),
    'English': np.random.randint(75, 100, 10)
}

df = pd.DataFrame(data)

print("📊 Student Grades Dataset:")
print(df)
print("\n📈 Summary Statistics:")
print(df.describe())

# %% [markdown]
# ## Part 3: Data Manipulation
#
# Let's perform some common data operations:

# %%
# Calculate average grade for each student
df['Average'] = df[['Math', 'Science', 'English']].mean(axis=1)

# Add a grade category
df['Grade'] = pd.cut(df['Average'], 
                      bins=[0, 70, 80, 90, 100],
                      labels=['C', 'B', 'A', 'A+'])

print("📊 Enhanced Dataset:")
print(df)

print("\n🏆 Top 3 Students:")
print(df.nlargest(3, 'Average')[['Student', 'Average', 'Grade']])

# %% [markdown]
# ## Part 4: Visualization
#
# Let's create a bar chart:

# %%
# Create visualization
plt.figure(figsize=(10, 6))

x = range(len(df))
width = 0.25

plt.bar([i - width for i in x], df['Math'], width, label='Math', color='#FF6B6B')
plt.bar(x, df['Science'], width, label='Science', color='#40C9D9')
plt.bar([i + width for i in x], df['English'], width, label='English', color='#6BCB77')

plt.xlabel('Students')
plt.ylabel('Grades')
plt.title('Student Performance Across Subjects', fontsize=14, fontweight='bold')
plt.xticks(x, df['Student'], rotation=45)
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

print("✅ Visualization created successfully!")

# %% [markdown]
# ## 🎯 Try It Yourself!
#
# Now it's your turn! Try these challenges:
#
# 1. **Calculate**: Find the student with the highest Science score
# 2. **Filter**: Show only students with Average >= 85
# 3. **Plot**: Create a line plot showing average grades
# 4. **Analyze**: What's the correlation between Math and Science scores?
#
# Use the cell below to experiment:

# %%
# Your code here!

# %% [markdown]
# ## 💡 Tips for Using JupyterLite
#
# - **Run cells**: Press `Shift + Enter` to execute a cell
# - **Add cells**: Click the `+` button in the toolbar
# - **Cell types**: Code or Markdown (for text/documentation)
# - **Save work**: File → Download (work is stored in browser)
# - **Restart kernel**: Kernel → Restart (clears all variables)
#
# ## 📚 Next Steps
#
# - Explore the [Playground](/playground/00_playground.html) for more examples
# - Check out [Course Materials](/materials/0_materials.html) for assignments
# - Visit the [Home page](/) for course information
#
# ---
#
# **Happy coding! 🚀**
